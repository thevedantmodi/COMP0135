# %% [markdown]
# # Regression
#
# ## Example: Age predictor for Abalone
#
# Need to graph all features with `model`
#
# Given model with parameters, etc.
#     - predict method with data x_NF (so the data that we have collected)
#     - predict returns N1 array (predict : R^(N x F) -> R^(N x 1))
#
# ## Check
# x_NF where N = 4, F = 6
# y_N1 (usually 2D, so usually take the N1 over N approach)
#
# ## Training
#
# Now, how to make the model function that generates yhat?
#
# Inputs are in R^F, outputs are in R
#
# Remember, we are given some "precomputed" y's given some x's
#
# train the model on the precomputed data with `fit` method
#
# output: predicted outputs
#
# ## Evaluation
#
# input: pairs of yhats and ys
#
# output: scalar measure of error/quality
#
# residuals:
#
# RMSE recommended over MSE for sensible scale, interpretable units
# RMSE more sensitive to a few large errors than MAE
#
#
# ## Linear Regression
#
# w vector is weight vector, with dim F
# bias is a scalar
#
# Wish to minimize Least squares
#
# ## K nn regression
#
# K is num. neighbors
#
# Find K nearest vectors for x
# predict average y
#
# no training, using data as a lookup table
